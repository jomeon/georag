# %%
import langchain
print(langchain.__file__)
# Out:
# C:\Users\szymo\.conda\envs\georag\lib\site-packages\langchain\__init__.py

# %%
import os
import sys
from dotenv import load_dotenv

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.document_loader import PDFDocumentLoader
from src.chunker import TextChunker
from src.retriever import VectorStoreManager
from src.generator import RAGGenerator
from src.evaluator import RAGEvaluator


load_dotenv(os.path.join('..', '.env'))
print("Środowisko załadowane.")
# Out:
# Środowisko załadowane.

# %% [markdown]
# ### Wczytywanie i Chunkowanie

# %%
loader = PDFDocumentLoader(data_path="../data/raw")
documents = loader.load_documents()

chunker = TextChunker(chunk_size=1000, chunk_overlap=200)
chunked_docs = chunker.split_documents(documents)
# Out:
# 2026-04-30 15:45:30,190 - INFO - Wczytywanie plików z katalogu: ../data/raw
# 2026-04-30 15:45:30,191 - INFO - Ładowanie: lidar_podstawy.pdf
# 2026-04-30 15:45:30,418 - INFO - Pomyślnie załadowano 1 stron z dokumentów.
# 2026-04-30 15:45:30,419 - INFO - Rozpoczynam podział 1 stron na mniejsze fragmenty...
# 2026-04-30 15:45:30,419 - INFO - Podzielono tekst na 2 chunków.

# %% [markdown]
# ### Baza Wektorowa (Chroma)

# %%
vsm = VectorStoreManager(persist_directory="../data/processed/chroma_db")
db = vsm.build_database(chunked_docs)
# Out:
# 2026-04-30 15:45:30,437 - INFO - Inicjalizacja modelu embeddingowego (może to zająć chwilę przy pierwszym uruchomieniu)...
# 2026-04-30 15:45:30,439 - INFO - No device provided, using cpu
# 2026-04-30 15:45:30,695 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:30,720 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/modules.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:30,866 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-30 15:45:30,867 - WARNING - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-30 15:45:30,892 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:30,894 - INFO - Loading SentenceTransformer model from sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2.
# 2026-04-30 15:45:31,037 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:31,060 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:31,211 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:31,235 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/README.md "HTTP/1.1 200 OK"
# 2026-04-30 15:45:31,381 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:31,407 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/modules.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:31,556 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:31,581 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/sentence_bert_config.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:31,729 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-04-30 15:45:31,889 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:31,914 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config.json "HTTP/1.1 200 OK"
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# 2026-04-30 15:45:32,273 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 2026-04-30 15:45:32,424 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-04-30 15:45:32,592 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/video_preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-04-30 15:45:32,743 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-04-30 15:45:32,892 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:32,916 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:33,065 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:33,091 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:33,232 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:33,256 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/config.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:33,404 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:33,432 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:33,574 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:33,601 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:33,747 - INFO - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-30 15:45:33,902 - INFO - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-30 15:45:35,701 - INFO - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2 "HTTP/1.1 200 OK"
# 2026-04-30 15:45:36,023 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 15:45:36,048 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2/e8f8c211226b894fcb81acc59f3b34ba3efd5f42/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# 2026-04-30 15:45:36,204 - INFO - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2 "HTTP/1.1 200 OK"
# 2026-04-30 15:45:36,208 - INFO - Rozpoczynam wektoryzację 2 fragmentów i zapis do bazy Chroma...
# 2026-04-30 15:45:38,554 - INFO - Baza wektorowa została pomyślnie zbudowana i zapisana w ../data/processed/chroma_db.

# %% [markdown]
# ### Generacja odpowiedzi

# %%
generator = RAGGenerator(vector_store=db)

pytanie = "Jakie są główne zastosowania technologii LiDAR w geoinformatyce?"
odpowiedz = generator.ask(pytanie)

print(f"PYTANIE: {pytanie}\n")
print(f"ODPOWIEDŹ:\n{odpowiedz['answer']}\n")
print("ŹRÓDŁA:")
for doc in odpowiedz['context']:
    print(f"- Plik: {doc.metadata.get('source')}, Strona: {doc.metadata.get('page')}")
# Out:
# 2026-04-30 15:45:38,565 - INFO - Inicjalizacja modelu LLM: gemini-1.5-flash (temperature=0.0)
# 2026-04-30 15:45:38,617 - INFO - Zadaję pytanie: 'Jakie są główne zastosowania technologii LiDAR w geoinformatyce?'
# 2026-04-30 15:45:38,659 - INFO - AFC is enabled with max remote calls: 10.
# 2026-04-30 15:45:38,840 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent "HTTP/1.1 404 Not Found"
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\.conda\envs\georag\lib\site-packages\langchain_google_genai\chat_models.py:3071, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3070 try:
# -> 3071     response: GenerateContentResponse = self.client.models.generate_content(
#    3072         **request,
#    3073     )
#    3074 except ClientError as e:
#
# File ~\.conda\envs\georag\lib\site-packages\google\genai\models.py:6329, in Models.generate_content(self, model, contents, config)
#    6328 i += 1
# -> 6329 response = self._generate_content(
#    6330     model=model, contents=contents, config=parsed_config
#    6331 )
#    6333 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~\.conda\envs\georag\lib\site-packages\google\genai\models.py:4767, in Models._generate_content(self, model, contents, config)
#    4765 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4767 response = self._api_client.request(
#    4768     'post', path, request_dict, http_options
#    4769 )
#    4771 if config is not None and getattr(
#    4772     config, 'should_return_http_response', None
#    4773 ):
#
# File ~\.conda\envs\georag\lib\site-packages\google\genai\_api_client.py:1579, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1576 http_request = self._build_request(
#    1577     http_method, path, request_dict, http_options
#    1578 )
# -> 1579 response = self._request(http_request, http_options, stream=False)
#    1580 response_body = (
#    1581     response.response_stream[0] if response.response_stream else ''
#    1582 )
#
# File ~\.conda\envs\georag\lib\site-packages\google\genai\_api_client.py:1370, in BaseApiClient._request(self, http_request, http_options, stream)
#    1369     retry = tenacity.Retrying(**retry_kwargs)
# -> 1370     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1372 return self._retry(self._request_once, http_request, stream)
#
# File ~\.conda\envs\georag\lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~\.conda\envs\georag\lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\.conda\envs\georag\lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\.conda\envs\georag\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File ~\.conda\envs\georag\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File ~\.conda\envs\georag\lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~\.conda\envs\georag\lib\site-packages\google\genai\_api_client.py:1349, in BaseApiClient._request_once(self, http_request, stream)
#    1348   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1349 errors.APIError.raise_for_response(response)
#    1350 return HttpResponse(
#    1351     response.headers, response if stream else [response.text]
#    1352 )
#
# File ~\.conda\envs\georag\lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File ~\.conda\envs\georag\lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[5], line 4
#       1 generator = RAGGenerator(vector_store=db, model_name="gemini-1.5-flash")
#       3 pytanie = "Jakie są główne zastosowania technologii LiDAR w geoinformatyce?"
# ----> 4 odpowiedz = generator.ask(pytanie)
#       6 print(f"PYTANIE: {pytanie}\n")
#       7 print(f"ODPOWIEDŹ:\n{odpowiedz['answer']}\n")
#
# File ~\Documents\georag\src\generator.py:67, in RAGGenerator.ask(self, question)
#      63 """
#      64 Zadaje pytanie do systemu RAG i zwraca odpowiedź wraz ze źródłami.
#      65 """
#      66 logger.info(f"Zadaję pytanie: '{question}'")
# ---> 67 response = self.rag_chain.invoke({"input": question})
#      69 logger.info("Odpowiedź wygenerowana pomyślnie. Znalezione źródła:")
#      70 for i, doc in enumerate(response.get("context", [])):
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\base.py:5739, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5732 @override
#    5733 def invoke(
#    5734     self,
#    (...)
#    5737     **kwargs: Any | None,
#    5738 ) -> Output:
# -> 5739     return self.bound.invoke(
#    5740         input,
#    5741         self._merge_configs(config),
#    5742         **{**self.kwargs, **kwargs},
#    5743     )
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\base.py:3201, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3199                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3200             else:
# -> 3201                 input_ = context.run(step.invoke, input_, config)
#    3202 # finish the root run
#    3203 except BaseException as e:
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\passthrough.py:507, in RunnableAssign.invoke(self, input, config, **kwargs)
#     500 @override
#     501 def invoke(
#     502     self,
#    (...)
#     505     **kwargs: Any,
#     506 ) -> dict[str, Any]:
# --> 507     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\base.py:2104, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2100     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2101     with set_config_context(child_config) as context:
#    2102         output = cast(
#    2103             "Output",
# -> 2104             context.run(
#    2105                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2106                 func,
#    2107                 input_,
#    2108                 config,
#    2109                 run_manager,
#    2110                 **kwargs,
#    2111             ),
#    2112         )
#    2113 except BaseException as e:
#    2114     run_manager.on_chain_error(e)
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\config.py:486, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     484 if run_manager is not None and accepts_run_manager(func):
#     485     kwargs["run_manager"] = run_manager
# --> 486 return func(input, **kwargs)
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\passthrough.py:493, in RunnableAssign._invoke(self, value, run_manager, config, **kwargs)
#     488     msg = "The input to RunnablePassthrough.assign() must be a dict."
#     489     raise ValueError(msg)  # noqa: TRY004
#     491 return {
#     492     **value,
# --> 493     **self.mapper.invoke(
#     494         value,
#     495         patch_config(config, callbacks=run_manager.get_child()),
#     496         **kwargs,
#     497     ),
#     498 }
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\base.py:3925, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3920     with get_executor_for_config(config) as executor:
#    3921         futures = [
#    3922             executor.submit(_invoke_step, step, input, config, key)
#    3923             for key, step in steps.items()
#    3924         ]
# -> 3925         output = {
#    3926             key: future.result()
#    3927             for key, future in zip(steps, futures, strict=False)
#    3928         }
#    3929 # finish the root run
#    3930 except BaseException as e:
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\base.py:3926, in <dictcomp>(.0)
#    3920     with get_executor_for_config(config) as executor:
#    3921         futures = [
#    3922             executor.submit(_invoke_step, step, input, config, key)
#    3923             for key, step in steps.items()
#    3924         ]
#    3925         output = {
# -> 3926             key: future.result()
#    3927             for key, future in zip(steps, futures, strict=False)
#    3928         }
#    3929 # finish the root run
#    3930 except BaseException as e:
#
# File ~\.conda\envs\georag\lib\concurrent\futures\_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~\.conda\envs\georag\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~\.conda\envs\georag\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\base.py:3909, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3903 child_config = patch_config(
#    3904     config,
#    3905     # mark each step as a child run
#    3906     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3907 )
#    3908 with set_config_context(child_config) as context:
# -> 3909     return context.run(
#    3910         step.invoke,
#    3911         input_,
#    3912         child_config,
#    3913     )
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\base.py:5739, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5732 @override
#    5733 def invoke(
#    5734     self,
#    (...)
#    5737     **kwargs: Any | None,
#    5738 ) -> Output:
# -> 5739     return self.bound.invoke(
#    5740         input,
#    5741         self._merge_configs(config),
#    5742         **{**self.kwargs, **kwargs},
#    5743     )
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\runnables\base.py:3201, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3199                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3200             else:
# -> 3201                 input_ = context.run(step.invoke, input_, config)
#    3202 # finish the root run
#    3203 except BaseException as e:
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_google_genai\chat_models.py:2559, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2556         msg = "Tools are already defined.code_execution tool can't be defined"
#    2557         raise ValueError(msg)
# -> 2559 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\language_models\chat_models.py:471, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     457 @override
#     458 def invoke(
#     459     self,
#    (...)
#     464     **kwargs: Any,
#     465 ) -> AIMessage:
#     466     config = ensure_config(config)
#     467     return cast(
#     468         "AIMessage",
#     469         cast(
#     470             "ChatGeneration",
# --> 471             self.generate_prompt(
#     472                 [self._convert_input(input)],
#     473                 stop=stop,
#     474                 callbacks=config.get("callbacks"),
#     475                 tags=config.get("tags"),
#     476                 metadata=config.get("metadata"),
#     477                 run_name=config.get("run_name"),
#     478                 run_id=config.pop("run_id", None),
#     479                 **kwargs,
#     480             ).generations[0][0],
#     481         ).message,
#     482     )
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\language_models\chat_models.py:1749, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1740 @override
#    1741 def generate_prompt(
#    1742     self,
#    (...)
#    1746     **kwargs: Any,
#    1747 ) -> LLMResult:
#    1748     prompt_messages = [p.to_messages() for p in prompts]
# -> 1749     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\language_models\chat_models.py:1556, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1553 for i, m in enumerate(input_messages):
#    1554     try:
#    1555         results.append(
# -> 1556             self._generate_with_cache(
#    1557                 m,
#    1558                 stop=stop,
#    1559                 run_manager=run_managers[i] if run_managers else None,
#    1560                 **kwargs,
#    1561             )
#    1562         )
#    1563     except BaseException as e:
#    1564         if run_managers:
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_core\language_models\chat_models.py:1896, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1894     result = generate_from_stream(iter(chunks))
#    1895 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1896     result = self._generate(
#    1897         messages, stop=stop, run_manager=run_manager, **kwargs
#    1898     )
#    1899 else:
#    1900     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_google_genai\chat_models.py:3075, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3071     response: GenerateContentResponse = self.client.models.generate_content(
#    3072         **request,
#    3073     )
#    3074 except ClientError as e:
# -> 3075     _handle_client_error(e, request)
#    3077 return _response_to_result(response)
#
# File ~\.conda\envs\georag\lib\site-packages\langchain_google_genai\chat_models.py:166, in _handle_client_error(e, request)
#     164 model_name = request.get("model", "unknown")
#     165 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 166 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-1.5-flash' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %% [markdown]
# ### Ewaluacja (LLM-as-a-Judge)

# %%
evaluator = RAGEvaluator(model_name="gemini-1.5-flash")

context_text = "\n".join([doc.page_content for doc in odpowiedz['context']])

faithfulness = evaluator.evaluate_faithfulness(pytanie, context_text, odpowiedz['answer'])
relevance = evaluator.evaluate_relevance(pytanie, odpowiedz['answer'])

print("--- WYNIKI EWALUACJI ---")
print(f"Faithfulness (Wierność): {faithfulness['evaluation']}")
print(f"Answer Relevance (Trafność): {relevance['evaluation']}")
